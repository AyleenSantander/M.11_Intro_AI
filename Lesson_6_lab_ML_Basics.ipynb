# %% [markdown]
# ## **Walkthrough of a Simple machine Learning Project cycle**
#
# ### **_Future Sales Prediction_**
# This dataset provides information about the sales of a product and the advertising expenditures incurred by the business across various platforms. The following is a description of each column in the dataset:
#
# - **TV**: Advertising cost spent in dollars for advertising on TV;
# - **Radio**: Advertising cost spent in dollars for advertising on Radio;
# - **Newspaper**: Advertising cost spent in dollars for advertising on Newspaper;
# - **Sales**: Number of units sold;
#
#
# In this dataset, the sales of the product are influenced by the advertising expenditures across different platforms. With this understanding of the dataset, the following section will guide you through the process of predicting future sales using machine learning techniques in Python.

# %% [markdown]
# ### **Data Collection or Loading**

# %%
# %pip install pandas numpy scikit-learn
# Out:
# Requirement already satisfied: pandas in C:\Users\aylee\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.0.5)
# Requirement already satisfied: numpy in C:\Users\aylee\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (2.5.3)
# Requirement already satisfied: scikit-learn in C:\Users\aylee\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (1.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\aylee\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\aylee\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\aylee\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn) (1.18.1)
# Requirement already satisfied: joblib>=1.4.0 in C:\Users\aylee\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn) (1.6.0)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Users\aylee\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn) (2.26.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in C:\Users\aylee\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: cloudpickle>=3.0 in C:\Users\aylee\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from joblib>=1.4.0->scikit-learn) (3.1.2)
# Requirement already satisfied: six>=1.5 in C:\Users\aylee\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib inline

# %%
# Import libraries and load the dataset
# You might need to load the data into the same directory

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

data = pd.read_csv("advertising.csv")
print(data.head())
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %% [markdown]
# ### **EDA and Data Preprocessing**

# %%
# Let’s have a look at whether this dataset contains any null values or not

print(data.isnull().sum())
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\aylee\AppData\Local\Python\pythoncore-3.14-64\python.exe

# %%
# %pip install plotly
# Out:
# Requirement already satisfied: plotly in C:\Users\aylee\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (7.0.0)
# Requirement already satisfied: narwhals>=1.15.1 in C:\Users\aylee\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from plotly) (2.26.0)
# Requirement already satisfied: packaging in C:\Users\aylee\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from plotly) (26.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in C:\Users\aylee\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (0.15.0)
# Requirement already satisfied: numpy<3,>=1.23.5 in C:\Users\aylee\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from statsmodels) (2.5.3)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in C:\Users\aylee\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from statsmodels) (1.18.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in C:\Users\aylee\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from statsmodels) (3.0.5)
# Requirement already satisfied: patsy>=0.5.6 in C:\Users\aylee\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from statsmodels) (1.0.3)
# Requirement already satisfied: packaging>=21.3 in C:\Users\aylee\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from statsmodels) (26.3)
# Requirement already satisfied: formulaic>=1.1.0 in C:\Users\aylee\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from statsmodels) (1.2.2)
# Requirement already satisfied: interface-meta>=1.2.0 in C:\Users\aylee\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from formulaic>=1.1.0->statsmodels) (2.0.1)
# Requirement already satisfied: narwhals>=1.17 in C:\Users\aylee\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from formulaic>=1.1.0->statsmodels) (2.26.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in C:\Users\aylee\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from formulaic>=1.1.0->statsmodels) (4.16.0)
# Requirement already satisfied: wrapt>=1.17.0rc1 in C:\Users\aylee\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from formulaic>=1.1.0->statsmodels) (2.4.1rc1)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\aylee\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\aylee\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2026.3)
# Requirement already satisfied: six>=1.5 in C:\Users\aylee\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Let's Visualise the data
# Visualise relationship between amount spendt on platforms and theie corresponding units sold

import plotly.express as px
import plotly.graph_objects as go

# TV

figure = px.scatter(data_frame = data, x="sales", # Changed 'Sales' to 'sales'
                    y="TV", size="TV", trendline="ols")
figure.show()

# %%
figure = px.scatter(data_frame = data, x="sales", # Changed 'Sales' to 'sales' to match the column name
                    y="newspaper", size="newspaper", trendline="ols")
figure.show()

# %%
# Radio
figure = px.scatter(data_frame = data, x="sales",
                    y="radio", size="radio", trendline="ols")
figure.show()

# %% [markdown]
# **Exercise**:
# You have just done a repetitive task to visualise similar data  for the three platforms, there is an opportunity here to use reusable function.
#
# Create a function to perform the plots by taking the column name as parameters

# %%
# @title Create a function to visualise the data
# exercise

# def <call-it-a-suitable-name(camelCase)>:
  #the rest of the function goes here
import plotly.express as px

def visualizeSalesData(data, platform):
  """
  Visualizes the relationship between advertising expenditure on a given platform and sales.

  Args:
    data: The pandas DataFrame containing the advertising data.
    platform: The name of the advertising platform (e.g., "TV", "radio", "newspaper").

  Returns:
    None. Displays the generated scatter plot.
  """

  # Use the original platform name instead of converting to lowercase to match column name
  figure = px.scatter(data_frame=data,
                      x="sales",
                      y=platform,
                      size=platform,
                      trendline="ols")
  figure.show()

# Example usage:
visualizeSalesData(data, "TV") # Changed "tV" to "TV" to match the column name
visualizeSalesData(data, "radio")
visualizeSalesData(data, "newspaper")

# %%
# let’s have a look at the correlation of all the columns with the sales column:

correlation = data.corr()

print(correlation["sales"].sort_values(ascending=False))
# Out:
# sales        1.000000
# TV           0.782224
# radio        0.576223
# newspaper    0.228299
# Name: sales, dtype: float64

# %% [markdown]
# ###**ML Model Training**

# %%
# Before training, we need to create train and test Split

# Before training, we need to create train and test Split

x = np.array(data.drop(columns=["sales"])) # Use columns keyword instead of positional argument for axis
y = np.array(data["sales"])
xtrain, xtest, ytrain, ytest = train_test_split(x, y,
                                                test_size=0.2,
                                                random_state=42)

# %%
# Now let’s train the model to predict future sales

model = LinearRegression() # this is a model we earlier imported from sklearn.linear_model
model.fit(xtrain, ytrain)

print(model.score(xtest, ytest))
# Out:
# 0.899438024100912

# %% [markdown]
# ###**Model Evaluation**
#
# **Exercise**
#
# Discuss methods to evaluate the performance of this ML trained model and implement one of the methods.
#
# Is this model reliable to predict sales? Why not?

# %%
# model evaluation
# Model evaluation using R-squared
r_squared = model.score(xtest, ytest)
print(f"R-squared: {r_squared}")
# Out:
# R-squared: 0.899438024100912

# %% [markdown]
# ### **Model Prediction**

# %%
#features = [[TV, Radio, Newspaper]]

features = np.array([[230.1, 37.8, 69.2]])
print(model.predict(features))
# Out:
# [20.61397147]
