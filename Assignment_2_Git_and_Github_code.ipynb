# %% [markdown]
# <a href="https://colab.research.google.com/github/AyleenSantander/M.11_Intro_AI/blob/main/Assignment_2_Git_and_Github_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Assignment 2: Git and GitHub Version Control and Code for AI Course
# Name Ayleen Santander

# %% [markdown]
# # Git and GitHub Assignment 2
# This notebook demonstrates basic Git operations.

# %% [markdown]
# #1. Python functions to the notebook

# %%
def multiply_numbers(a, b):
    return a * b
print(multiply_numbers(3, 4))
# Out:
# 12

# %%
def divide_numbers(a, b):
   if b != 0:
        return a / b
   else:
    return "Cannot divide by zero"
print(divide_numbers(10, 2))
# Out:
# 5.0

# %%
def sum_numbers(a, b):
    return a + b

print(sum_numbers(440, 300))
# Out:
# 740
